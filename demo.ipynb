# %%
import pandas as pd
import numpy as np
from google.cloud import bigquery

# %%
client = bigquery.Client(project="a-cubed-dev")

job_config = bigquery.QueryJobConfig(
    allow_large_results=True
)

# %%
results = client.query(query="SELECT * FROM a-cubed-dev.raw_data.nyc_dcp_pluto LIMIT 1000", job_config=job_config)
df = results.to_dataframe()
# Out:
# /Users/jennyli/Desktop/Projects/demo/.venv/lib/python3.10/site-packages/google/cloud/bigquery/table.py:1933: UserWarning: BigQuery Storage module not found, fetch data with the REST endpoint instead.
#   warnings.warn(

# %%
df.head()
# Out:
#   borough           block           lot    cd ct2010 cb2010 schooldist  \
# 0      BX  2980.000000000  45.000000000  None   None   None       None
# 1      MN   939.000000000   6.000000000  None   None   None       None
# 2      BK  1736.000000000  35.000000000  None   None   None       None
# 3      SI  7440.000000000  75.000000000  None   None   None       None
# 4      SI  6828.000000000  56.000000000  None   None   None       None
#
#   council zipcode firecomp  ... pfirm15_flag spdist1 edesignum dcpedited  \
# 0    None    None     None  ...         None    None      None      None
# 1    None    None     None  ...         None    None      None      None
# 2    None    None     None  ...         None    None      None      None
# 3    None    None     None  ...         None    None      None      None
# 4    None    None     None  ...         None    None      None         t
#
#   firm07_flag overlay2  zonedist3 spdist2 ltdheight zonedist4
# ...
